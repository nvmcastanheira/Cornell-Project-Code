# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy.integrate import RK45

# %%
i = 0.0+1.0j
print(np.exp(i*100000000000000*np.pi))
# Out:
# (0.9999356318333378-0.011346020891205282j)
